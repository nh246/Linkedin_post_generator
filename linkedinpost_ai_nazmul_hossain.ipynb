# %% [markdown]
# ## Install packages

# %%
# !pip install -q --upgrade langchain langchain-google-genai google-generativeai

# %% [markdown]
# ## Imports & API Key

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
import google.generativeai as genai

# API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyDJVP_Fv8S530onBzdwNp_HSiEjmIM3Rgc"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %% [markdown]
# ## Initialize LLM

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.7,
    max_output_tokens=600
)

# %% [markdown]
# ## Prompt Template (Optimized for reliable output)

# %%
prompt = PromptTemplate.from_template(
    """You are a professional LinkedIn content creator. Generate a engaging, structured LinkedIn post on the topic: {topic}.
    Write it entirely in {language}.

    Structure:
    - Paragraph 1: Attention-grabbing hook.
    - Paragraphs 2-3: 1-2 key insights or tips.
    - Paragraph 4: Call-to-action (e.g., "Share your thoughts below!").

    Keep it 2-4 paragraphs total. Professional tone, 1-2 emojis, 3-4 relevant hashtags at the end.

    Output ONLY the post content, nothing else."""
)

# %% [markdown]
# ## Create the LangChain

# %%
chain = LLMChain(llm=llm, prompt=prompt)

# %% [markdown]
# ## Input, Run with Fallback & Debug

# %%
topic = input("Enter topic: ").strip()
language = input("Enter language: ").strip()

print("\nRunning...")

try:
    #  LangChain
    result = chain.invoke({"topic": topic, "language": language})

    # Extract text
    if isinstance(result, dict):
        post = result.get("text", "") or str(result).strip()
    else:
        post = str(result).strip()

    if not post or len(post) < 50:
        raise ValueError("Short/empty response from LangChain")

except Exception as e:
    print(f"LangChain issue: {e}")
    print("Using direct Google API...")

    # DIRECT FALLBACK
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt_text = f"""You are a professional LinkedIn content creator. Generate a engaging, structured LinkedIn post on the topic: {topic}.
    Write it entirely in {language}.

    Structure:
    - Paragraph 1: Attention-grabbing hook.
    - Paragraphs 2-3: 1-2 key insights or tips.
    - Paragraph 4: Call-to-action (e.g., "Share your thoughts below!").

    Keep it 2-4 paragraphs total. Professional tone, 1-2 emojis, 3-4 relevant hashtags at the end.

    Output ONLY the post content, nothing else."""

    response = model.generate_content(prompt_text)
    post = response.text.strip()

# Display
print("\n" + "="*70)
print(" GENERATED LINKEDIN POST (AI Agent Output) ".center(70))
print("="*70)
print(post)
print("="*70)
print(f"\n Success! Topic: {topic} | Language: {language}")
# Out:
# Enter topic: AI in Healthcare
# Enter language: English
#
# Running...
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# Is AI the stethoscope of the future? 🩺 It's certainly making waves in healthcare, and we're just scratching the surface of its potential. From faster diagnoses to personalized treatment plans, the possibilities seem limitless.
#
# One game-changing application is AI-powered image analysis. Forget poring over countless scans – AI algorithms can now detect anomalies in X-rays, MRIs, and CT scans with incredible speed and accuracy, potentially catching diseases in their earliest, most treatable stages. Another area ripe for disruption is drug discovery. AI can analyze vast datasets to identify promising drug candidates, accelerating the development process and bringing life-saving medications to market faster.
#
# But let's not forget the human element. While AI excels at data analysis and pattern recognition, empathy and critical thinking remain uniquely human strengths. The most effective healthcare solutions will likely involve a collaborative approach, where AI empowers clinicians to make better-informed decisions and deliver more compassionate care.
#
# What are your thoughts on the role of AI in healthcare? Share your insights and predictions in the comments below! Let's discuss the future of medicine. 👇 #AIinHealthcare #HealthcareInnovation #ArtificialIntelligence #DigitalHealth
# ======================================================================
#
#  Success! Topic: AI in Healthcare | Language: English

# %% [markdown]
# ##  Continuous Input Loop — exits when user types 'exit' or 'quit'

# %%
while True:
    topic = input("\nEnter topic (or type 'exit' to quit): ").strip()
    if topic.lower() in ["exit", "quit"]:
        print("\n👋 Exiting program. Goodbye!")
        break

    language = input("Enter language (or type 'exit' to quit): ").strip()
    if language.lower() in ["exit", "quit"]:
        print("\n👋 Exiting program. Goodbye!")
        break

    print("\n⚙️ Running... please wait...\n")

    try:
        # LangChain
        result = chain.invoke({"topic": topic, "language": language})

        # Extract text
        if isinstance(result, dict):
            post = result.get("text", "") or str(result).strip()
        else:
            post = str(result).strip()

        if not post or len(post) < 50:
            raise ValueError("Short/empty response from LangChain")

    except Exception as e:
        print(f"⚠️ LangChain issue: {e}")
        print("Using direct Google API fallback...\n")

        # DIRECT FALLBACK
        model = genai.GenerativeModel('gemini-2.0-flash')
        prompt_text = f"""You are a professional LinkedIn content creator.
Generate an engaging, structured LinkedIn post on the topic: {topic}.
Write it entirely in {language}.

Structure:
- Paragraph 1: Attention-grabbing hook.
- Paragraphs 2-3: 1-2 key insights or tips.
- Paragraph 4: Call-to-action (e.g., "Share your thoughts below!").

Keep it 2–4 paragraphs total. Professional tone, 1–2 emojis,
and 3–4 relevant hashtags at the end.

Output ONLY the post content, nothing else."""

        response = model.generate_content(prompt_text)
        post = response.text.strip()

    # Display result
    print("\n" + "="*70)
    print(" GENERATED LINKEDIN POST (AI Agent Output) ".center(70))
    print("="*70)
    print(post)
    print("="*70)
    print(f"\n Success! Topic: {topic} | Language: {language}")
# Out:
# Enter topic (or type 'exit' to quit): Remote Work Productivity
# Enter language (or type 'exit' to quit): Bengali
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# ঘরে বসে কাজ, মানেই কি প্রোডাক্টিভিটি কমে যাওয়া? 🤔 একদমই না! বরং কিছু কৌশল অবলম্বন করলে, রিমোট ওয়ার্কিং হতে পারে প্রোডাক্টিভিটির অন্যতম হাতিয়ার।
#
# প্রথমত, নিজের জন্য একটি নির্দিষ্ট রুটিন তৈরি করুন। ঘুম থেকে ওঠা থেকে শুরু করে কাজের সময়, সবকিছু গুছিয়ে নিন। এতে আপনার মন প্রস্তুত থাকবে এবং কাজ করার স্পৃহা বাড়বে। দ্বিতীয়ত, কাজের পরিবেশকে গুরুত্ব দিন। একটি শান্ত ও গোছানো জায়গা বেছে নিন, যেখানে কোনো রকম distractions থাকবে না। আরামদায়ক চেয়ার এবং পর্যাপ্ত আলোর ব্যবস্থাও প্রোডাক্টিভিটির জন্য জরুরি।
#
# আরেকটি গুরুত্বপূর্ণ বিষয় হলো, নিয়মিত বিরতি নেওয়া। একটানা কাজ না করে, প্রতি ঘন্টায় ৫-১০ মিনিটের জন্য বিরতি নিন। এই সময়টুকুতে একটু হাঁটাহাঁটি করুন, জল পান করুন অথবা হালকা স্ট্রেচিং করুন। এতে আপনার মনোযোগ বাড়বে এবং ক্লান্তি দূর হবে।
#
# রিমোট ওয়ার্কিং প্রোডাক্টিভিটি নিয়ে আপনার মতামত কী? নিচে কমেন্ট করে জানান! 👇
#
# #রিমোট_ওয়ার্ক #কর্মদক্ষতা #ওয়ার্ক_ফ্রম_হোম #প্রোডাক্টিভিটি_টিপস
# ======================================================================
#
#  Success! Topic: Remote Work Productivity | Language: Bengali
#
# Enter topic (or type 'exit' to quit): gen ai
# Enter language (or type 'exit' to quit): Spanish
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# ¿Sientes la ola de la IA Generativa acercándose? 🌊 No estás solo. La GenAI está transformando industrias a una velocidad vertiginosa, y entender cómo aprovecharla es crucial para el éxito futuro.
#
# Una clave para dominar la GenAI es enfocarse en la experimentación. No tengas miedo de probar diferentes modelos y herramientas para identificar las que mejor se adapten a tus necesidades específicas. Además, recuerda que la calidad de los datos de entrenamiento es fundamental. "Garbage in, garbage out" sigue siendo una regla de oro.
#
# Otro aspecto vital es la ética y la responsabilidad. Asegúrate de implementar salvaguardias para evitar sesgos y garantizar la transparencia en el uso de la IA. El futuro de la GenAI depende de nuestra capacidad para usarla de manera responsable.
#
# ¿Cómo estás integrando la IA Generativa en tu trabajo o negocio? ¡Comparte tus experiencias y perspectivas en los comentarios! Me encantaría leer tus ideas. 👇
#
# #InteligenciaArtificial #GenAI #IAgenerativa #Tecnología
# ======================================================================
#
#  Success! Topic: gen ai | Language: Spanish
#
# Enter topic (or type 'exit' to quit): ai in marketing
# Enter language (or type 'exit' to quit): english
#
# ⚙️ Running... please wait...
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# Is your marketing strategy feeling a little…robotic? 😉 It might be time to embrace the *actual* robots! AI is no longer a futuristic fantasy; it's revolutionizing how we connect with customers, personalize experiences, and drive measurable results.
#
# One game-changing application is AI-powered content creation. Tools can now assist with generating compelling copy variations, brainstorming fresh ideas, and even optimizing headlines for maximum click-through rates. Think of it as having a tireless, data-driven assistant dedicated to perfecting your messaging. Another powerful use is in predictive analytics, allowing you to anticipate customer behavior and tailor your campaigns for optimal impact. Forget guesswork – AI provides the insights to make informed decisions.
#
# Ready to supercharge your marketing efforts with the power of AI? There are fantastic resources and platforms available to get you started, regardless of your technical expertise. Don't get left behind in this AI-powered marketing revolution!
#
# What AI tools are you leveraging in your marketing strategy? Share your thoughts below! 👇 #AIinMarketing #ArtificialIntelligence #MarketingAutomation #DigitalMarketing
# ======================================================================
#
#  Success! Topic: ai in marketing | Language: english
#
# Enter topic (or type 'exit' to quit): ai in traffic control
# Enter language (or type 'exit' to quit): English
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# Stuck in traffic again? 🚗 What if I told you AI could be the key to smoother commutes and safer roads? We're not just talking about self-driving cars; AI is revolutionizing traffic control systems right now.
#
# One of the biggest breakthroughs is AI's ability to analyze massive datasets in real-time. Imagine traffic lights that dynamically adjust their timing based on current conditions, predicting congestion before it even happens and optimizing flow accordingly. This means reduced delays, lower fuel consumption, and a smaller carbon footprint. Another key benefit is improved safety. AI-powered systems can identify potential hazards, like accidents or pedestrian crossings, and adapt traffic signals to prevent collisions.
#
# But the implementation isn't without its challenges. Data privacy concerns, algorithm bias, and the need for robust infrastructure are all factors that need careful consideration. The key is to approach this technology responsibly, ensuring fairness and transparency in its deployment.
#
# What are your thoughts on the role of AI in shaping the future of traffic management? Share your insights and experiences in the comments below! Let's discuss the potential and the challenges. 👇 #AIinTraffic #SmartCities #TrafficManagement #Innovation
# ======================================================================
#
#  Success! Topic: ai in traffic control | Language: English
#
# Enter topic (or type 'exit' to quit): AI in education
# Enter language (or type 'exit' to quit): Bangla
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# শিক্ষাখাতে এআই: সম্ভাবনা নাকি শঙ্কা? 🤔 আজ এই গুরুত্বপূর্ণ বিষয়টি নিয়ে কিছু কথা বলতে চাই।
#
# এআই এখন আর ভবিষ্যতের গল্প নয়, বরং বর্তমানের বাস্তবতা। শিক্ষাখাতে এর ব্যবহার শিক্ষার্থীদের জন্য ব্যক্তিগতকৃত শিক্ষা (Personalized Learning) নিশ্চিত করতে পারে। প্রতিটি শিক্ষার্থীর শেখার গতি এবং আগ্রহ ভিন্ন। এআই সেই অনুযায়ী কন্টেন্ট তৈরি এবং উপস্থাপন করতে পারে, যা শেখাকে আরও কার্যকর করে তুলবে। এছাড়াও, শিক্ষকরা প্রশাসনিক কাজের চাপ কমিয়ে শিক্ষার্থীদের প্রতি আরও বেশি মনোযোগ দিতে পারবেন।
#
# তবে, প্রযুক্তির অতিরিক্ত নির্ভরতা এবং ডেটা সুরক্ষা নিয়েও আমাদের সতর্ক থাকতে হবে। এআই যেন শিক্ষক-শিক্ষার্থীর মধ্যেকার মানবিক সংযোগকে দুর্বল না করে, সেদিকে খেয়াল রাখতে হবে। সঠিক পরিকল্পনা এবং বাস্তবায়নের মাধ্যমেই শিক্ষাখাতে এআই-এর সুফল নিশ্চিত করা সম্ভব।
#
# শিক্ষাখাতে এআই-এর ব্যবহার নিয়ে আপনার মতামত কী? নিচে কমেন্ট করে জানান! 👇
# #এআইশিক্ষা #শিক্ষা #প্রযুক্তি #ভবিষ্যৎশিক্ষা
# ======================================================================
#
#  Success! Topic: AI in education | Language: Bangla
#
# Enter topic (or type 'exit' to quit): what is LangChain
# Enter language (or type 'exit' to quit): english
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# Ever feel like AI is a brilliant but scattered genius? 🤯 LangChain is the glue that helps structure that brilliance, turning raw AI power into practical, real-world applications. Think of it as the framework that lets you chain together different AI models, data sources, and tools to create complex, intelligent workflows.
#
# LangChain's power lies in its ability to handle complex tasks like document analysis, chatbots, and even code generation. It provides modules for things like prompt management, memory, chains (linking sequences of calls), and agents (dynamic decision-making). This modularity allows developers to build custom AI solutions tailored to specific needs, rather than being limited to pre-packaged models.
#
# Want to dive deeper? Start by exploring LangChain's documentation and experimenting with simple chains. The possibilities are truly endless!
#
# What are some of the coolest LangChain projects you've seen or are working on? Share your thoughts below! 👇 #LangChain #AI #ArtificialIntelligence #MachineLearning
# ======================================================================
#
#  Success! Topic: what is LangChain | Language: english
#
# Enter topic (or type 'exit' to quit): What is llm
# Enter language (or type 'exit' to quit): english
#
# ⚙️ Running... please wait...
#
#
# ======================================================================
#               GENERATED LINKEDIN POST (AI Agent Output)
# ======================================================================
# Ever feel like AI is suddenly everywhere, spitting out text, code, and even art? The engine behind much of this magic is the Large Language Model, or LLM. But what *is* an LLM, really? 🤔
#
# Essentially, LLMs are sophisticated AI models trained on massive datasets of text and code. They learn patterns and relationships within that data, enabling them to generate human-like text, translate languages, answer questions, and even write different kinds of creative content. Think of them as incredibly advanced autocomplete systems, but instead of just predicting the next word, they can generate entire paragraphs or even scripts!
#
# One crucial thing to understand is that LLMs don't actually "understand" the information they process. They are masterful at identifying patterns and generating outputs that statistically make sense based on their training data. This is why critical thinking and fact-checking are essential when using LLM-generated content.
#
# What are your experiences with LLMs? Have you used them for writing, coding, or something else entirely? Share your thoughts below! 👇
#
# #LLM #AI #ArtificialIntelligence #MachineLearning
# ======================================================================
#
#  Success! Topic: What is llm | Language: english
#
# Enter topic (or type 'exit' to quit): exit
#
# 👋 Exiting program. Goodbye!

# %% [markdown]
# ## Video link for google drive
#
# https://drive.google.com/file/d/1BoK2WneCtpMgaMMC4vCp-CEP_0qr5Ar8/view?usp=sharing
